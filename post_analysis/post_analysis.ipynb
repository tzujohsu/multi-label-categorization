# %%
# mlflow ui --backend-store-uri 'file:/Users/kiyas/Library/Application Support/zenml/local_stores/b043a600-6573-4111-9f6d-5ec1cd2a0363/mlruns'
import pandas as pd
import sklearn
import numpy as np
import warnings
from sklearn.exceptions import InconsistentVersionWarning

warnings.filterwarnings("ignore", category=InconsistentVersionWarning)

# %%
import pickle

# Load the pickle file
with open('/Users/kiyas/Library/Application Support/zenml/local_stores/b043a600-6573-4111-9f6d-5ec1cd2a0363/model_building_step/sklearn_pipeline/060e62c2-9c80-4aab-a673-a85d868a8a15/b6b24df6/artifact.pkl', 'rb') as file:
    pipeline = pickle.load(file)

print(pipeline)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=LGBMClassifier(learning_rate=0.08,
#                                                                 n_estimators=350,
#                                                                 num_leaves=35,
#                                                                 verbose=-1)))])

# %%
N = 10
vectorizer = pipeline.named_steps['tfidf']
feature_names = vectorizer.get_feature_names_out()

categories = ['crime, law and justice', 'arts, culture, entertainment and media',
       'economy, business and finance',
       'disaster, accident and emergency incident', 'environment',
       'education', 'health', 'human interest', 'lifestyle and leisure',
       'politics', 'labour', 'religion and belief',
       'science and technology', 'society', 'sport',
       'conflict, war and peace', 'weather']

feature_importance_dict = {}

for i, category in enumerate(categories):
    lgbm_model = pipeline.named_steps['clf'].estimators_[i]  # Get LGBM for this category
    importance = lgbm_model.feature_importances_
    top_n_idx = np.argsort(-importance)[:N]  # Get indices of top N important features
    feature_importance_dict[category] = [feature_names[idx] for idx in top_n_idx]

# Convert to DataFrame for readability
df = pd.DataFrame(feature_importance_dict).T
df.columns = [f"{i+1}" for i in range(df.shape[1])]
df = df.T

# %%
df
# Out:
#    crime, law and justice arts, culture, entertainment and media  \
# 1                     law                              entertain
# 2                   polic                                 cultur
# 3                  murder                                 tradit
# 4                 sentenc                                   movi
# 5                   court                                     th
# 6                  justic                                   news
# 7                investig                                    art
# 8                   crime                                 museum
# 9                   offic                                   film
# 10                  innoc                                   game
#
#    economy, business and finance disaster, accident and emergency incident  \
# 1                        compani                                      fire
# 2                        economi                                     emerg
# 3                         market                                     crash
# 4                         econom                                     incid
# 5                         custom                                    disast
# 6                        product                                     accid
# 7                          stock                                      also
# 8                         growth                                   wildfir
# 9                            ceo                                     damag
# 10                          show                                      road
#
#     environment education     health human interest lifestyle and leisure  \
# 1        climat      educ     health          plant                  game
# 2   environment    school     hospit       ceremoni                garden
# 3        pollut   student     diseas          award               exercis
# 4         spill    parent      medic       birthday                tattoo
# 5       environ   univers  treatment         celebr               workout
# 6        forest     learn    patient            dog                  said
# 7       wildlif     build        nhs    anniversari                   fit
# 8        insect     cours      virus            day                   gym
# 9         speci   teacher       care            pet                   you
# 10        emiss      said  healthcar         garden               classic
#
#    politics    labour religion and belief science and technology  society  \
# 1     polit       job              religi                 scienc   immigr
# 2     trump     retir              church               research      fan
# 3    govern   employe              muslim                 clinic   school
# 4    polici      work               mosqu                   math    peopl
# 5     elect    labour           christian                   said      wed
# 6    religi     union                educ                    use    trump
# 7     right      wage            religion                  space  chariti
# 8     googl    worker              jewish               scientif   addict
# 9    worker    employ                pope                   educ  societi
# 10     vote  unemploy               islam                   test   refuge
#
#            sport conflict, war and peace     weather
# 1          sport                 protest     weather
# 2        stadium                     war       storm
# 3            gym                    coup       flood
# 4        footbal                  terror        rain
# 5         player               terrorist         met
# 6         athlet                  attack    forecast
# 7          leagu                  syrian        wind
# 8          muscl                militari      across
# 9      bodybuild                  unrest  temperatur
# 10  championship                    peac        warn

# %%
df.to_csv('model_feature_importance.csv', index=False)

# %%
import joblib 
# compress to a smaller size
joblib.dump(pipeline, "model.joblib", compress=3)
# Out:
# ['model.joblib']
